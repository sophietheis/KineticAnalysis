# %% [markdown]
# # Import

# %%
import os

import numpy as np
import pandas as pd

from kineticanalysis.analysis.combination import combine_tracks_df

# %% [markdown]
# # Input value

# %%
path = ""
f_name = "data.csv"

# nb of combine track together
nb_track = 2

# nb of track created
nb_combination = 10

# %% [markdown]
# # Combine tracks

# %%
df = pd.read_csv(os.path.join(path, f_name))
results = combine_tracks_df(df, nb_combination, nb_track)

# %%
results.to_csv(os.path.join(path, "combine_track.csv"))
